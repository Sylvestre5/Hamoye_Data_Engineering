# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
Read_data = pd.read_csv("https://bit.ly/HDSC-StageOneDataset")

# %%
Read_data.head

# %%
Read_data.describe(include='all')
# Out:
#                       record_id  utility_id_ferc1   report_year  \
# count                     29523      29523.000000  29523.000000
# unique                    29523               NaN           NaN
# top     f1_fuel_2014_12_101_0_1               NaN           NaN
# freq                          1               NaN           NaN
# mean                        NaN        118.601836   2005.806050
# std                         NaN         74.178353      7.025483
# min                         NaN          1.000000   1994.000000
# 25%                         NaN         55.000000   2000.000000
# 50%                         NaN        122.000000   2006.000000
# 75%                         NaN        176.000000   2012.000000
# max                         NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
Read_data.isnull()
# Out:
#        record_id  utility_id_ferc1  report_year  plant_name_ferc1  \
# 0          False             False        False             False
# 1          False             False        False             False
# 2          False             False        False             False
# 3          False             False        False             False
# 4          False             False        False             False
# ...          ...               ...          ...               ...
# 29518      False             False        False             False
# 29519      False             False        False             False
# 29520      False             False        False             False
# 29521      False             False        False             False
# 29522      False             False        False             False
#
#        fuel_type_code_pudl  fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 0                    False      False            False                False
# ...

# %%
Electric_Utility = Read_data.to_csv("Electric_Utility.csv")

# %%
Read_data.sum()
# Out:
# record_id                       f1_fuel_1994_12_1_0_7f1_fuel_1994_12_1_0_10f1_...
# utility_id_ferc1                                                          3501482
# report_year                                                              59217412
# plant_name_ferc1                rockportrockport total plantgorgasbarrychickas...
# fuel_type_code_pudl             coalcoalcoalcoalgascoalnuclearcoalcoalcoalgasc...
# fuel_qty_burned                                                       7.74128e+10
# fuel_mmbtu_per_unit                                                        250713
# fuel_cost_per_unit_burned                                             6.15995e+06
# fuel_cost_per_unit_delivered                                          2.70894e+07
# fuel_cost_per_mmbtu                                                        569922
# dtype: object

# %%
Read_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
Read_data.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
Read_data[['fuel_unit']] = Read_data[['fuel_unit']].fillna(value='mcf')

# %%
Read_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
Read_data.fuel_unit.describe
# Out:
# <bound method NDFrame.describe of 0        ton
# 1        ton
# 2        ton
# 3        ton
# 4        mcf
#         ...
# 29518    mcf
# 29519    mcf
# 29520    mcf
# 29521    ton
# 29522    mcf
# Name: fuel_unit, Length: 29523, dtype: object>

# %%
Read_data.groupby('report_year')['report_year'].count()
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
Read_data.groupby('fuel_type_code_pudl').first()
# Out:
#                                   record_id  utility_id_ferc1  report_year  \
# fuel_type_code_pudl
# coal                  f1_fuel_1994_12_1_0_7                 1         1994
# gas                  f1_fuel_1994_12_2_0_10                 2         1994
# nuclear               f1_fuel_1994_12_2_1_1                 2         1994
# oil                   f1_fuel_1994_12_6_0_2                 6         1994
# other                f1_fuel_1994_12_11_0_6                11         1994
# waste                 f1_fuel_1994_12_9_0_3                 9         1994
#
#                      plant_name_ferc1 fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                         rockport       ton        5377489.0
# gas                         chickasaw       mcf          40533.0
# nuclear              joseph m. farley       kgU           2260.0
# oil                      clinch river       bbl           6510.0
# other                      w.f. wyman       bbl          55652.0
# ...

# %%
Read_data.groupby('report_year').first()
# Out:
#                            record_id  utility_id_ferc1    plant_name_ferc1  \
# report_year
# 1994           f1_fuel_1994_12_1_0_7                 1            rockport
# 1995         f1_fuel_1995_12_200_0_1               200    aroostook valley
# 1996         f1_fuel_1996_12_204_0_1               204            seabrook
# 1997           f1_fuel_1997_12_1_0_7                 1  rockport total aeg
# 1998           f1_fuel_1998_12_1_0_7                 1  rockport total aeg
# 1999         f1_fuel_1999_12_141_0_1               141            boardman
# 2000         f1_fuel_2000_12_141_0_1               141            boardman
# 2001         f1_fuel_2001_12_195_0_1               195           pulliam 3
# 2002         f1_fuel_2002_12_195_0_1               195           pulliam 3
# 2003         f1_fuel_2003_12_283_0_1               283       talbot energy
# 2004           f1_fuel_2004_12_1_0_7                 1  rockport total aeg
# ...

# %%
read_df=Read_data.iloc[0:19000].reset_index(drop=True)
read_df2=Read_data.iloc[19000:].reset_index(drop=True)

# %%
assert len(Read_data) == (len(read_df) + len(read_df2))

# %%
pd.merge(read_df, read_df2, how="inner")
# Out:
# Empty DataFrame
# Columns: [record_id, utility_id_ferc1, report_year, plant_name_ferc1, fuel_type_code_pudl, fuel_unit, fuel_qty_burned, fuel_mmbtu_per_unit, fuel_cost_per_unit_burned, fuel_cost_per_unit_delivered, fuel_cost_per_mmbtu]
# Index: []

# %%
pd.merge(read_df, read_df2, how="outer")
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
pd.merge(read_df, read_df2, how="left")
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# ...                         ...               ...          ...
# 18995   f1_fuel_2009_12_182_1_9               182         2009
# 18996  f1_fuel_2009_12_182_1_10               182         2009
# 18997  f1_fuel_2009_12_182_1_13               182         2009
# 18998  f1_fuel_2009_12_182_1_14               182         2009
# 18999    f1_fuel_2009_12_79_0_1                79         2009
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
pd.merge(read_df, read_df2, how="right")
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_2009_12_79_0_2                79         2009
# 1       f1_fuel_2009_12_79_0_4                79         2009
# 2       f1_fuel_2009_12_79_0_5                79         2009
# 3       f1_fuel_2009_12_79_0_7                79         2009
# 4      f1_fuel_2009_12_79_0_10                79         2009
# ...                        ...               ...          ...
# 10518  f1_fuel_2018_12_12_0_13                12         2018
# 10519   f1_fuel_2018_12_12_1_1                12         2018
# 10520  f1_fuel_2018_12_12_1_10                12         2018
# 10521  f1_fuel_2018_12_12_1_13                12         2018
# 10522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  montrose                 oil       bbl          22912.0
# ...

# %%
new_data = Read_data
pd.concat([Read_data, new_data]).reset_index(drop=True)
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 59041  f1_fuel_2018_12_12_0_13                12         2018
# 59042   f1_fuel_2018_12_12_1_1                12         2018
# 59043  f1_fuel_2018_12_12_1_10                12         2018
# 59044  f1_fuel_2018_12_12_1_13                12         2018
# 59045  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
Read_data.duplicated().any()
# Out:
# False

# %%
plt.style.use('classic')
n = Read_data.fuel_qty_burned
y = Read_data.report_year
plt.plot(n, y, '-')
plt.fill(facecolor='g')
plt.title("Sample Data Visualization")
plt.grid(b=True, color='r', alpha=0.6, linestyle='-', linewidth=0.5)
plt.show()

# %%
ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(7,4))
plt.xticks(rotation = 90)
fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
g = sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale("log")
g.set_ylim(1, 12000)
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %%
import seaborn as sns
sample_df = Read_data.sample(n=50, random_state=4)
sns.regplot(x=sample_df["utility_id_ferc1"], y=sample_df["fuel_cost_per_mmbtu"], fit_reg=False)

# %%
sns.boxplot(x="fuel_type_code_pudl", y="utility_id_ferc1", palette=["m","g"], data=Read_data)

# %%
sns.kdeplot(sample_df["fuel_cost_per_unit_burned"], shade=True, color="b")
